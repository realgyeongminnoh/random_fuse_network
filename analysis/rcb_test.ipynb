# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))

from resistor_capacitor_battery.src.array import Array
from resistor_capacitor_battery.src.matrix import Matrix
from resistor_capacitor_battery.src.equation import Equation
from resistor_capacitor_battery.src.failure import Failure
from resistor_capacitor_battery.breakdown import breakdown as breakdown_rcb

# %%
length = 30
width = 2.0
seed = 0
val_cap = 100.0

# %%
array = Array(length=length)
matrix = Matrix(matrix_init=None, array=array, val_cap=val_cap)
equation = Equation(array=array, matrix=matrix)
failure = Failure(array=array, matrix=matrix, equation=equation, width=width, seed=seed, save_volts_profile=True)

# %%
solve = equation.solve_init
break_edge = failure.break_edge_init
solve()
break_edge()

solve = equation.solve
break_edge = failure.break_edge
for _ in range(array.length - 1):
    solve()
    break_edge()

check_graph = equation.check_graph
while check_graph():
    solve()
    break_edge()

# %% [markdown]
# ---
# ---
# ---

# %%
from analysis.src.datum import Datum
datum = Datum(failure)
datum.check_profile(), datum.check_connectivity(), datum.check_num_cycle()

# %%
signed, size_fig, size_obj, rainbow = False, 5, 2, True
datum.draw_profile("edge", signed, size_fig, size_obj, rainbow)
datum.draw_profile("stress", signed, size_fig, size_obj, rainbow)
datum.draw_profile("cap", signed, size_fig, size_obj, rainbow)
datum.draw_profile("cond", signed, size_fig, size_obj, rainbow)

# %%
size_fig, size_obj, draw_dual = 10.0, 2.0, True
save, pad_inches, transparent = False, 0.7, False
datum.initialize_graph(size_fig, size_obj, draw_dual, save, pad_inches, transparent)

idxs_edge_broken, num_edge_broken_rainbow, with_labels = None, 0, False
datum.draw_graph(idxs_edge_broken, num_edge_broken_rainbow, with_labels)

# %% [markdown]
# ---
# ---
# ---

# %%
from analysis.src.data import Data
data = Data(model="resistor_capacitor_battery", val_cap="1.0")

# %%
check_volts_ext = data.check_volts_ext(); print(check_volts_ext)
check_connectivity = data.check_connectivity(); print(check_connectivity)
check_num_cycle = data.check_num_cycle(); print(check_num_cycle)
# Out:
# []
# []
# []

# %%
data.config_to_num_seed
# Out:
# {(10, 0.25): 1000,
#  (10, 0.5): 1000,
#  (10, 0.75): 1000,
#  (10, 1.0): 1000,
#  (10, 1.25): 1000,
#  (10, 1.5): 1000,
#  (10, 1.75): 1000,
#  (10, 2.0): 1000,
#  (20, 0.25): 1000,
#  (20, 0.5): 1000,
#  (20, 0.75): 1000,
#  (20, 1.0): 1000,
#  (20, 1.25): 1000,
#  (20, 1.5): 1000,
#  (20, 1.75): 1000,
#  (20, 2.0): 1000,
#  (30, 0.25): 1000,
#  (30, 0.5): 1000,
#  (30, 0.75): 1000,
#  (30, 1.0): 1000,
#  (30, 1.25): 1000,
#  (30, 1.5): 1000,
#  (30, 1.75): 1000,
#  (30, 2.0): 1000,
#  (40, 0.25): 1000,
#  (40, 0.5): 1000,
#  (40, 0.75): 1000,
#  (40, 1.0): 1000,
#  (40, 1.25): 1000,
#  (40, 1.5): 1000,
#  (40, 1.75): 1000,
#  (40, 2.0): 1000,
#  (50, 0.25): 1000,
#  (50, 0.5): 1000,
#  (50, 0.75): 1000,
#  (50, 1.0): 1000,
#  (50, 1.25): 1000,
#  (50, 1.5): 1000,
#  (50, 1.75): 1000,
#  (50, 2.0): 1000,
#  (60, 0.25): 1000,
#  (60, 0.5): 1000,
#  (60, 0.75): 1000,
#  (60, 1.0): 1000,
#  (60, 1.25): 1000,
#  (60, 1.5): 1000,
#  (60, 1.75): 1000,
#  (60, 2.0): 1000,
#  (70, 0.25): 1000,
#  (70, 0.5): 1000,
#  (70, 0.75): 1000,
#  (70, 1.0): 1000,
#  (70, 1.25): 1000,
#  (70, 1.5): 1000,
#  (70, 1.75): 1000,
#  (70, 2.0): 1000,
#  (80, 0.25): 1000,
#  (80, 0.5): 1000,
#  (80, 0.75): 1000,
#  (80, 1.0): 1000,
#  (80, 1.25): 1000,
#  (80, 1.5): 1000,
#  (80, 1.75): 1000,
#  (80, 2.0): 1000,
#  (90, 0.25): 1000,
#  (90, 0.5): 692}
